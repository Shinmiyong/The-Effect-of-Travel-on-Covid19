# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import seaborn as sns

# %%
df = pd.read_csv('./tmap_total/tmap_total_1.csv')

# %%
# multi_indexing
df.set_index(['년도','지역 시군구'], inplace= True)

# %%
df.head(10)
# Out:
#               여행 횟수
# 년도   지역 시군구
# 2020 강원 정선군     345
#      강원 평창군     330
#      강원 고성군     315
# 2019 전북 무주군     311
#      강원 평창군     309
#      강원 정선군     306
# 2020 전북 무주군     296
# 2019 강원 고성군     292
# 2020 제주 서귀포시    279
# 2019 강원 홍천군     275

# %%
indexs = df.index
print(indexs)
# Out:
# MultiIndex([(2020,  '강원 정선군'),
#             (2020,  '강원 평창군'),
#             (2020,  '강원 고성군'),
#             (2019,  '전북 무주군'),
#             (2019,  '강원 평창군'),
#             (2019,  '강원 정선군'),
#             (2020,  '전북 무주군'),
#             (2019,  '강원 고성군'),
#             (2020, '제주 서귀포시'),
#             (2019,  '강원 홍천군')],
#            names=['년도', '지역 시군구'])

# %%
index = []
for i in range(0, len(indexs)):
    a = indexs[i][1]
    index.append(a)
print(index)
# Out:
# ['강원 정선군', '강원 평창군', '강원 고성군', '전북 무주군', '강원 평창군', '강원 정선군', '전북 무주군', '강원 고성군', '제주 서귀포시', '강원 홍천군']

# %%
# 팔레트 리스트로 설정
colors = []
for i in range(0, 10):
    if indexs[i][0] == 2020:
        colors.append('lightcoral')
    else:
        colors.append('deepskyblue')
print(colors)
# Out:
# ['lightcoral', 'lightcoral', 'lightcoral', 'deepskyblue', 'deepskyblue', 'deepskyblue', 'lightcoral', 'deepskyblue', 'lightcoral', 'deepskyblue']

# %%
font_path = '../malgun.ttf'
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font_name)

# %%
plt.figure(figsize= (16, 10))
#sns.barplot(data= df, x= '여행 횟수', y= index)

travel = sns.barplot(data= df, x= '여행 횟수', y= indexs, palette=colors)
travel.set_title('2019년/2020년 1월 여행 횟수', size = 20) 
travel.yaxis.set_visible(False)               # yaxis 안보이게 하기
plt.text(345, 8, '2020년', va = 'center', ha = 'center', fontsize = 20, color = 'lightcoral')
plt.text(345, 8.5, '2019년', va = 'center', ha = 'center', fontsize = 20, color = 'deepskyblue')
ax = travel
for i, p in enumerate(ax.patches):
    width = p.get_width()
    plt.text(5+p.get_width(), p.get_y()+0.5*p.get_height(),
                 '{:1.0f}'.format(width),
                 ha='center', va='center', fontsize=20)
    
    plt.text(55, p.get_y()+0.5*p.get_height(), str(index[i]), ha='center', va='center', fontsize=20)

plt.show()
